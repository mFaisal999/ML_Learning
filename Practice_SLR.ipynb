# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/ML/indian population.xlsx")
df
# Out:
#     Sr. No.  Year  Population
# 0         1  2050  1639176033
# 1         2  2045  1620619200
# 2         3  2040  1592691513
# 3         4  2035  1553723810
# 4         5  2030  1503642322
# 5         6  2025  1445011620
# 6         7  2020  1380004385
# 7         8  2019  1366417754
# 8         9  2018  1352642280
# 9        10  2017  1338676785
# 10       11  2016  1324517249
# 11       12  2015  1310152403

# %%
plt.scatter(df.Year,df.Population)

# %%
plt.xlabel('Year', color = 'black')
plt.ylabel('Population', color = 'black')
plt.scatter(df.Year,df.Population)

# %%
lr = linear_model.LinearRegression()
lr.fit( df [['Year']], df.Population)
# Out:
# LinearRegression()

# %%
lr.predict([[2033]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.50700975e+09])

# %%
lr.predict([[2048]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.65629193e+09])

# %%
lr.predict([[2088]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.05437775e+09])

# %%
lr.score( df [ [ 'Year' ] ] , df.Population)
# Out:
# 0.9761872908797182

# %%
lr.coef_
# Out:
# array([9952145.54984894])

# %%
lr.intercept_
# Out:
# np.float64(-18725702156.152065)

# %%
# y = mx + b

9952145.54984894 * 2088 + -18725702156.152065
# Out:
# 2054377751.9325218

# %%
plt.xlabel('Year', color = 'black')
plt.ylabel('Population', color = 'black')
plt.scatter(df.Year,df.Population)

plt.plot( df.Year, lr.predict(df[['Year']]), color = 'red')
